# %% [markdown]
# jdlaksjdaklsdajhsjdhas <- Jupyer will not consider this as code.
#
# # Title
# ## Subtitle
# ###...
#
# _Italic_
# **Bold**

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(4+6)
# Out:
# 10

# %% [markdown]
# This is how you console print a sum in python.
